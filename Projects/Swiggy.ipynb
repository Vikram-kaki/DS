# %% [markdown]
# # Swiggy Data analysis

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as sk
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ## Read the data

# %%
file1 = pd.read_csv('./DataSets/swiggy.csv')

# %%
file1.head()
# Out:
#        id               name    city rating     rating_count   cost  \
# 0  567335     AB FOODS POINT  Abohar     --  Too Few Ratings  ₹ 200
# 1  531342  Janta Sweet House  Abohar    4.4      50+ ratings  ₹ 200
# 2  158203  theka coffee desi  Abohar    3.8     100+ ratings  ₹ 100
# 3  187912          Singh Hut  Abohar    3.7      20+ ratings  ₹ 250
# 4  543530      GRILL MASTERS  Abohar     --  Too Few Ratings  ₹ 250
#
#                       cuisine          lic_no  \
# 0            Beverages,Pizzas  22122652000138
# 1               Sweets,Bakery  12117201000112
# 2                   Beverages  22121652000190
# 3            Fast Food,Indian  22119652000167
# 4  Italian-American,Fast Food  12122201000053
#
#                                                 link  \
# 0  https://www.swiggy.com/restaurants/ab-foods-po...
# 1  https://www.swiggy.com/restaurants/janta-sweet...
# 2  https://www.swiggy.com/restaurants/theka-coffe...
# 3  https://www.swiggy.com/restaurants/singh-hut-n...
# 4  https://www.swiggy.com/restaurants/grill-maste...
#
#                                              address              menu
# 0  AB FOODS POINT, NEAR RISHI NARANG DENTAL CLINI...  Menu/567335.json
# 1  Janta Sweet House, Bazar No.9, Circullar Road,...  Menu/531342.json
# 2         theka coffee desi, sahtiya sadan road city  Menu/158203.json
# 3    Singh Hut, CIRCULAR ROAD NEAR NEHRU PARK ABOHAR  Menu/187912.json
# 4  GRILL MASTERS, ADA Heights, Abohar - Hanumanga...  Menu/543530.json

# %%
file1.tail()
# Out:
#             id                      name      city rating     rating_count  \
# 148536  553122          The Food Delight  Yavatmal     --  Too Few Ratings
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     --  Too Few Ratings
# 148538  559435           Cafe Bella Ciao  Yavatmal     --  Too Few Ratings
# 148539  418989               GRILL ZILLA  Yavatmal     --  Too Few Ratings
# 148540  447770            Lazeez kitchen  Yavatmal     --  Too Few Ratings
#
#          cost           cuisine          lic_no  \
# 148536  ₹ 200  Fast Food,Snacks  21522053000452
# 148537  ₹ 300            Pizzas         license
# 148538  ₹ 300  Fast Food,Snacks  21522251000378
# 148539  ₹ 250       Continental  21521251000241
# 148540  ₹ 200            Pizzas  21521251000634
#
#                                                      link  \
# 148536  https://www.swiggy.com/restaurants/the-food-de...
# 148537  https://www.swiggy.com/restaurants/maitri-food...
# 148538  https://www.swiggy.com/restaurants/cafe-bella-...
# 148539  https://www.swiggy.com/restaurants/grill-zilla...
# 148540  https://www.swiggy.com/restaurants/lazeez-kitc...
#
#                                                   address              menu
# 148536  The Food Delight, 94MC+X35, New Singhania Naga...  Menu/553122.json
# 148537  MAITRI FOODS & BEVERAGES, POLIC MITRYA SOCIETY...  Menu/562647.json
# 148538  Cafe Bella Ciao, SHOP NO 2 NEMANI MARKET SBI S...  Menu/559435.json
# 148539  GRILL ZILLA, SHO NO 2/6, POSTEL GROUND CHOWPAT...  Menu/418989.json
# 148540  Lazeez kitchen, 94G3+2RR, Wadgaon, Yavatmal, M...  Menu/447770.json

# %%
file1.sample(10)
# Out:
#             id                  name                               city  \
# 73236   516579      SIDDAH'S KITCHEN  Kothapet & Dilsukhnagar,Hyderabad
# 146804  489291       Anil Fast Foods             Governorpet,Vijayawada
# 95538   402491        NIRMALA SNACKS                  Lake Town,Kolkata
# 1710    482851       A One Pani Puri                     GOTA,Ahmedabad
# 45519    50456           Burger King             Gandhipuram,Coimbatore
# 34496    66941        Hotel Top City                OMR Navalur,Chennai
# 145133   95765  Basant Bahar Delight                           Varanasi
# 77076   559104           GUNTUR MESS                 Madhapur,Hyderabad
# 99044   422622         DELHI CHHOLEY                Gomti Nagar,Lucknow
# 65286    96857  Singh Biryani Corner                          Gorakhpur
#
#        rating     rating_count   cost                    cuisine  \
# 73236      --  Too Few Ratings  ₹ 150  South Indian,North Indian
# 146804     --  Too Few Ratings  ₹ 200          Chinese,Beverages
# 95538      --  Too Few Ratings  ₹ 300             Indian,Chinese
# 1710       --  Too Few Ratings  ₹ 300          Chaat,Street Food
# 45519     4.1      1K+ ratings  ₹ 350         American,Fast Food
# 34496      --  Too Few Ratings  ₹ 400       North Indian,Chinese
# 145133     --  Too Few Ratings  ₹ 200         Continental,Snacks
# 77076     4.2      20+ ratings  ₹ 250                     Indian
# 99044      --  Too Few Ratings  ₹ 300             Indian,Chinese
# 65286     3.6      50+ ratings  ₹ 200       North Indian,Chinese
#
#                 lic_no                                               link  \
# 73236   13622012000128  https://www.swiggy.com/restaurants/siddahs-kit...
# 146804  20121006002717  https://www.swiggy.com/restaurants/anil-fast-f...
# 95538   22820013001617  https://www.swiggy.com/restaurants/nirmala-sna...
# 1710    20721038001290  https://www.swiggy.com/restaurants/a-one-pani-...
# 45519   12417003002424  https://www.swiggy.com/restaurants/burger-king...
# 34496   12419008000049  https://www.swiggy.com/restaurants/hotel-top-c...
# 145133  12719038000245  https://www.swiggy.com/restaurants/basant-baha...
# 77076   23622032001109  https://www.swiggy.com/restaurants/guntur-mess...
# 99044   22721743000479  https://www.swiggy.com/restaurants/delhi-chhol...
# 65286   12718627000211  https://www.swiggy.com/restaurants/singh-birya...
#
#                                                   address              menu
# 73236   SIDDAH'S KITCHEN, Plot no:36, Road, No: 1B, Ch...  Menu/516579.json
# 146804  Anil Fast Foods, D.no-26-13-72, Jagapathi Inte...  Menu/489291.json
# 95538   NIRMALA SNACKS, 300, BANGUR AVENUE, BLOCK B, K...  Menu/402491.json
# 1710    A One Pani Puri, Opp Dev Residency Near Panchs...  Menu/482851.json
# 45519   Burger King, Burger King India Pvt Ltd, Brooke...   Menu/50456.json
# 34496   Hotel Top City, No. 236F, Kumaran Nagar, OMR, ...   Menu/66941.json
# 145133  Basant Bahar Delight, C7/285, Shanti Tower, Ra...   Menu/95765.json
# 77076   GUNTUR MESS, C9WR+QRC, Ayyappa Society, Chanda...  Menu/559104.json
# 99044   DELHI CHHOLEY, C-218 Sahara Plaza, Vikas Khand...  Menu/422622.json
# 65286   Singh Biryani Corner, Golghar  Gorakhpur  Utta...   Menu/96857.json

# %% [markdown]
# ## Data Cleaning

# %%
file1.isna().sum()
# Out:
# id                0
# name             86
# city              0
# rating           86
# rating_count     86
# cost            131
# cuisine          99
# lic_no          229
# link              0
# address          86
# menu              0
# dtype: int64

# %%
file1.shape
# Out:
# (148541, 11)
